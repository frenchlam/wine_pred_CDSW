# %%
# !pip3 install sklearn
# Out:
# Requirement already satisfied: sklearn in /home/cdsw/.local/lib/python3.6/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/cdsw/.local/lib/python3.6/site-packages (from sklearn) (0.21.3)
# Requirement already satisfied: joblib>=0.11 in /home/cdsw/.local/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.14.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.3.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.13.3)
# WARNING: You are using pip version 19.1.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd

input_file = "../data/WineNewGBTDataSet.csv"
col_Names=["fixedAcidity",
    "volatileAcidity",
    "citricAcid",
    "residualSugar",
    "chlorides",
    "freeSulfurDioxide",
    "totalSulfurDioxide",
    "density",
    "pH",
    "sulphates",
    "Alcohol",
    "Quality"]

# comma delimited is the default
wine_df = pd.read_csv(input_file,sep=";",header=None, names=col_Names)
wine_df.head()
# Out:
#    fixedAcidity  volatileAcidity  citricAcid  residualSugar  chlorides  \
# 0           7.4             0.70        0.00            1.9      0.076
# 1           7.8             0.88        0.00            2.6      0.098
# 2           7.8             0.76        0.04            2.3      0.092
# 3          11.2             0.28        0.56            1.9      0.075
# 4           7.4             0.70        0.00            1.9      0.076
#
#    freeSulfurDioxide  totalSulfurDioxide  density    pH  sulphates  Alcohol  \
# 0               11.0                34.0   0.9978  3.51       0.56      9.4
# 1               25.0                67.0   0.9968  3.20       0.68      9.8
# 2               15.0                54.0   0.9970  3.26       0.65      9.8
# 3               17.0                60.0   0.9980  3.16       0.58      9.8
# 4               11.0                34.0   0.9978  3.51       0.56      9.4
#
#      Quality
# 0       Poor
# 1       Poor
# 2       Poor
# 3  Excellent
# 4       Poor

# %%
#check labels
print(wine_df.Quality.unique())
# Out:
# ['Poor' 'Excellent' '1']

# %%
#clean up and encode labels
wine_df.Quality.replace('1',"Excellent",inplace=True)
wine_df.describe()
# Out:
#        fixedAcidity  volatileAcidity   citricAcid  residualSugar    chlorides  \
# count   1599.000000      1599.000000  1599.000000    1599.000000  1599.000000
# mean       8.319637         0.527821     0.270976       2.538806     0.087467
# std        1.741096         0.179060     0.194801       1.409928     0.047065
# min        4.600000         0.120000     0.000000       0.900000     0.012000
# 25%        7.100000         0.390000     0.090000       1.900000     0.070000
# 50%        7.900000         0.520000     0.260000       2.200000     0.079000
# 75%        9.200000         0.640000     0.420000       2.600000     0.090000
# max       15.900000         1.580000     1.000000      15.500000     0.611000
#
#        freeSulfurDioxide  totalSulfurDioxide      density           pH  \
# count        1599.000000         1599.000000  1599.000000  1599.000000
# mean           15.874922           46.467792     0.996747     3.311113
# std            10.460157           32.895324     0.001887     0.154386
# min             1.000000            6.000000     0.990070     2.740000
# 25%             7.000000           22.000000     0.995600     3.210000
# 50%            14.000000           38.000000     0.996750     3.310000
# 75%            21.000000           62.000000     0.997835     3.400000
# max            72.000000          289.000000     1.003690     4.010000
#
#          sulphates      Alcohol
# count  1599.000000  1599.000000
# mean      0.658149    10.422983
# std       0.169507     1.065668
# min       0.330000     8.400000
# 25%       0.550000     9.500000
# 50%       0.620000    10.200000
# 75%       0.730000    11.100000
# max       2.000000    14.900000

# %%
#encode labels 
wine_df.Quality = pd.Categorical(wine_df.Quality)
wine_df['Label'] = wine_df.Quality.cat.codes
wine_df.head()
# Out:
#    fixedAcidity  volatileAcidity  citricAcid  residualSugar  chlorides  \
# 0           7.4             0.70        0.00            1.9      0.076
# 1           7.8             0.88        0.00            2.6      0.098
# 2           7.8             0.76        0.04            2.3      0.092
# 3          11.2             0.28        0.56            1.9      0.075
# 4           7.4             0.70        0.00            1.9      0.076
#
#    freeSulfurDioxide  totalSulfurDioxide  density    pH  sulphates  Alcohol  \
# 0               11.0                34.0   0.9978  3.51       0.56      9.4
# 1               25.0                67.0   0.9968  3.20       0.68      9.8
# 2               15.0                54.0   0.9970  3.26       0.65      9.8
# 3               17.0                60.0   0.9980  3.16       0.58      9.8
# 4               11.0                34.0   0.9978  3.51       0.56      9.4
#
#      Quality  Label
# 0       Poor      1
# 1       Poor      1
# 2       Poor      1
# 3  Excellent      0
# 4       Poor      1

# %%
#random forest Classifier Grid Search
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(wine_df.iloc[:,:11],wine_df['Label'],test_size=0.2, random_state=30)

#parameters for grid search
rfc = RandomForestClassifier(random_state=10, n_jobs=-1)

GS_params = { 
    'n_estimators': [25,30,35],
    'max_depth' : [7,9,11]
}

#Cross Validation Grid Search
CV_rfc = GridSearchCV(estimator=rfc, 
                      param_grid=GS_params, 
                      cv= 3, 
                      n_jobs=2,
                      verbose=2)
CV_rfc.fit(X_train, y_train)

#Show Best Parameters 
print(CV_rfc.best_params_)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# {'max_depth': 9, 'n_estimators': 30}
# [Parallel(n_jobs=2)]: Done  27 out of  27 | elapsed:    4.2s finished

# %%
#final Model
rfc_final= RandomForestClassifier(n_estimators=CV_rfc.best_params_['n_estimators'] , 
                                  max_depth=CV_rfc.best_params_['max_depth'], 
                                  random_state=10, 
                                  n_jobs=2,
                                  verbose=1)
rfc_final.fit(X_train, y_train)
y_true, y_pred = y_test, rfc_final.predict(X_test)
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  30 out of  30 | elapsed:    0.1s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  30 out of  30 | elapsed:    0.0s finished

# %%
#Evaluation metrics
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82       170
#            1       0.81      0.76      0.79       150
#
#     accuracy                           0.81       320
#    macro avg       0.81      0.80      0.80       320
# weighted avg       0.81      0.81      0.81       320

# %%
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_true, y_pred))
# Out:
# 0.803529411765
